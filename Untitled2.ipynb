# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from pylab import rcParams

# %%
df = pd.read_csv(r'C:\Users\Rahul Miglani\Downloads\heart-disease-uci\Heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# ## 1 pick a varaible and graph it 4 different ways

# %%
sns.kdeplot(df['thalach'])
plt.title('Max HR')
plt.xlabel('beats per minute')
# Out:
# Text(0.5, 0, 'beats per minute')

# %%
sns.boxplot(df['thalach'])
plt.title('Max HR')
plt.xlabel('beats per minute')
# Out:
# Text(0.5, 0, 'beats per minute')

# %%
sns.violinplot( df["thalach"] )
plt.title('Max HR')
plt.xlabel('beats per minute')
# Out:
# Text(0.5, 0, 'beats per minute')

# %%
sns.distplot(df['thalach'])
plt.title('Max HR')
plt.xlabel('beats per minute')
# Out:
# Text(0.5, 0, 'beats per minute')

# %% [markdown]
# ## 2 Two continous variables

# %%
sns.jointplot(df["age"], df["thalach"], kind='scatter',s=200, color='m', edgecolor="blue", linewidth=2)
plt.suptitle('Age vs max HR')
plt.subplots_adjust(top=0.9)

# %%
sns.jointplot(df["age"], df["thalach"], kind='kde', color='c')
plt.suptitle('Age vs max HR')
plt.subplots_adjust(top=0.9)

# %%
plt.plot( 'age', 'thalach', data=df, marker='o', color='mediumvioletred')
plt.suptitle('Age vs max HR')
plt.xlabel('Age')
plt.ylabel('Max HR')
plt.show()

# %%
sns.scatterplot(df['age'], df['thalach'])
plt.suptitle('Age vs max HR')
plt.xlabel('Age')
plt.ylabel('Max HR')
plt.show()

# %%
g = sns.barplot(x=df['age'], y=df['target'], palette="rocket",label='big')
rcParams['figure.figsize'] = 10, 20
plt.suptitle('disease occurance')
plt.xlabel('Age')
plt.ylabel('0 = nodisease')
plt.show()

# %%
# Plot of one catagorical variable and two numerical 
sns.lmplot( x="age", y="thalach", data=df, fit_reg=False, hue='sex', legend=False, palette="deep", scatter_kws={"alpha":1.0,"s":20} )
plt.suptitle('age vs max HR')
plt.xlabel('age')
plt.ylabel('Max HR')
plt.show()

# %% [markdown]
# ## 3. One continous and one catagorical

# %%
sns.boxplot( x=df["sex"], y=df["thalach"], data = df)
rcParams['figure.figsize'] = 5, 5
plt.suptitle('sex vs max HR')
plt.xlabel('Sex')
plt.ylabel('Max HR')
plt.show()

# %%
g = sns.catplot(x="sex", y="thalach", hue="sex", data=df,
                height=6, kind="bar", palette="muted")
g.despine(left=True)
g.set_ylabels("continous and categorical")

# %%
sns.boxplot(x="sex", y="thalach", data=df,
            whis="range", palette="vlag")
rcParams['figure.figsize'] = 10 , 5

# %%
sns.scatterplot(x="thalach", y="sex", hue = 'sex', palette="ch:r=-.2,d=.3_r", data = df)

# %%
ax = sns.boxplot(x='cp',y='chol',hue='sex',data=df)  
plt.title('chest pain and cholestrol in male and females')
sns.despine(offset=0, trim=True)
ax.set(xlabel='chest pain level', ylabel='cholestrol')

plt.show()

# %%
sns.boxenplot(x="cp", y="trestbps",
              color="b", 
              scale="linear", data=df)

# %%
sns.swarmplot(x="age", y="thalach", hue="cp", palette=["r", "c", "y",'b'], data=df)
rcParams['figure.figsize'] = 20, 5

# %%
fig, axes = plt.subplots( nrows=2, ncols=3, figsize=(10,10) )
plt.subplots_adjust( wspace=0.30, hspace=0.20, top=0.98 )
bins = np.linspace(20, 80, 15)
axes[0,0].hist(df[df.target>0].slope.tolist(),color=["blue"],histtype="step",label="disease",density=True)
axes[0,0].hist(df[df.target==0].slope,color=["red"],histtype="step",label="no disease",density=True)
axes[0,0].set_xlabel("slope")
axes[0,0].legend(prop={'size': 10},loc="upper right")
axes[0,0].legend(prop={'size': 10},loc="upper left")
axes[0,1].hist(df[df.target>0].thalach.tolist(),color=["blue"],histtype="step",label="disease",density= False)
axes[0,1].hist(df[df.target==0].thalach,color=["red"],histtype="step",label="no disease",density=False)
axes[0,1].set_xlabel("thalach")
axes[0,1].legend(prop={'size': 10},loc="upper left")
axes[0,2].hist(df[df.target>0].cp.tolist(),color=["blue"],histtype="step",label="disease",density=True)
axes[0,2].hist(df[df.target==0].cp,color=["red"],histtype="step",label="no disease",density=True)
axes[0,2].set_xlabel("Type of Chest Pain [cp]")
axes[0,2].legend(prop={'size': 10},loc="upper left")
axes[1,0].hist(df[df.target>0].chol.tolist(),color = ['blue'],histtype='step' ,label='disease')
axes[1,0].hist(df[df.target==0].chol,color=['red'],histtype = 'step',label = 'no disease')
axes[1,0].set_xlabel('serum cholesterol')
# Out:
# Text(0.5, 0, 'serum cholesterol')

# %% [markdown]
# #### bins = np.linspace(20, 80, 15)
# plt.hist(df[df.target>0].age.tolist(),bins,color=["crimson"],histtype="step",label="disease",density=True)
# plt.hist(df[df.target==0].age,bins,color=["chartreuse"],histtype="step",label="no disease",density=True)
# plt.show()

# %%
# Compute the correlation matrix
corr = df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 5, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
k = 5
cols = df.corr().nlargest(k, 'target')['target'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, cmap="RdYlGn", fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# Attributes auch as Chest pain , thalach, slope and restecg are highly correlated to the Target. Chest pain is the most effective way to figure out if someone has heart disease or not. Thalach is the maximum HR achieved by the patient. Slope is the slope of the peak excersice ST segement.

# %%
prob = df.groupby(['cp', 'thalach'])['slope'].value_counts(normalize=True).reset_index(name='prob')

# %%
g = sns.PairGrid(prob)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels=6);

# %%
sns.lmplot( x="cp", y="thalach", data=prob, fit_reg=False, hue='prob', legend=False, palette="deep", scatter_kws={"alpha":1.0,"s":20} )
plt.suptitle('Prob of HD')
plt.xlabel('cp')
plt.ylabel('Max HR')
plt.show()
